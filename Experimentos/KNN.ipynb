# %% [markdown]
# # Ejecución algoritmo k-NN

# %%
# !python knn.py
# Out:
# Failed to start the Kernel 'proyecto_ia_clase (Python 3.12.10)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. WebSocket is not defined
