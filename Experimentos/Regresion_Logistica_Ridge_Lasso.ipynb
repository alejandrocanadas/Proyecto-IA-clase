# %% [markdown]
# # Ejecucion algoritmos ridge y lasso

# %%
print("hola")
# Out:
# Failed to start the Kernel 'proyecto_ia_clase (Python 3.13.1)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. WebSocket is not defined

# %%
# !python ridge_lasso.py
